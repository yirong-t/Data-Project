# %%
import pandas as pd

# Read a sample of the data
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
# df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz')

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    prefix + 'yellow_tripdata_2021-01.csv.gz',
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
# Check data shape
df.shape
# Out:
# (1369765, 18)

# %%
# Check data types
df.dtypes
# Out:
# VendorID                          Int64
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                   Int64
# trip_distance                   float64
# RatecodeID                        Int64
# store_and_fwd_flag               string
# PULocationID                      Int64
# DOLocationID                      Int64
# payment_type                      Int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
# Display first rows
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.80                   2.5
# 1                    0.3          4.30                   0.0
# 2                    0.3         51.95                   0.0
# 3                    0.3         36.35                   0.0
# 4                    0.3         24.36                   2.5

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_iter = pd.read_csv(
    prefix + 'yellow_tripdata_2021-01.csv.gz',
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000
)

# %%
# for df_chunk in df_iter:
    # print(len(df_chunk))
# Out:
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 69765

# %%
first = True

for df_chunk in df_iter:

    if first:
        # Create table schema (no data)
        df_chunk.head(0).to_sql(
            name="yellow_taxi_data",
            con=engine,
            if_exists="replace"
        )
        first = False
        print("Table created")

    # Insert chunk
    df_chunk.to_sql(
        name="yellow_taxi_data",
        con=engine,
        if_exists="append"
    )

    print("Inserted:", len(df_chunk))
# Out:
# Table created
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# Inserted: 100000
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[10], line 16
#      12         first = False
#      13         print("Table created")
#      14
#      15     # Insert chunk
# ---> 16     df_chunk.to_sql(
#      17         name="yellow_taxi_data",
#      18         con=engine,
#      19         if_exists="append"
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:840, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     835 elif not isinstance(frame, DataFrame):
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
# --> 840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#    (...)    852         **engine_kwargs,
#     853     )
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/pandas/io/sql.py:1658, in SQLDatabase.__exit__(self, *args)
#    1656 def __exit__(self, *args) -> None:
#    1657     if not self.returns_generator:
# -> 1658         self.exit_stack.close()
#
# File ~/.local/share/uv/python/cpython-3.13.13-linux-x86_64-gnu/lib/python3.13/contextlib.py:627, in ExitStack.close(self)
#     625 def close(self):
#     626     """Immediately unwind the context stack."""
# --> 627     self.__exit__(None, None, None)
#
# File ~/.local/share/uv/python/cpython-3.13.13-linux-x86_64-gnu/lib/python3.13/contextlib.py:619, in ExitStack.__exit__(self, *exc_details)
#     615 try:
#     616     # bare "raise exc" replaces our carefully
#     617     # set-up context
#     618     fixed_ctx = exc.__context__
# --> 619     raise exc
#     620 except BaseException:
#     621     exc.__context__ = fixed_ctx
#
# File ~/.local/share/uv/python/cpython-3.13.13-linux-x86_64-gnu/lib/python3.13/contextlib.py:604, in ExitStack.__exit__(self, *exc_details)
#     602 else:
#     603     exc_details = type(exc), exc, exc.__traceback__
# --> 604 if cb(*exc_details):
#     605     suppressed_exc = True
#     606     pending_raise = False
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:147, in TransactionalContext.__exit__(self, type_, value, traceback)
#     145     self.commit()
#     146 except:
# --> 147     with util.safe_reraise():
#     148         if self._rollback_can_be_called():
#     149             self.rollback()
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:145, in TransactionalContext.__exit__(self, type_, value, traceback)
#     143 if type_ is None and self._transaction_is_active():
#     144     try:
# --> 145         self.commit()
#     146     except:
#     147         with util.safe_reraise():
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2642, in Transaction.commit(self)
#    2626 """Commit this :class:`.Transaction`.
#    2627
#    2628 The implementation of this may vary based on the type of transaction in
#    (...)   2639
#    2640 """
#    2641 try:
# -> 2642     self._do_commit()
#    2643 finally:
#    2644     assert not self.is_active
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2747, in RootTransaction._do_commit(self)
#    2744 assert self.connection._transaction is self
#    2746 try:
# -> 2747     self._connection_commit_impl()
#    2748 finally:
#    2749     # whether or not commit succeeds, cancel any
#    2750     # nested transactions, make this transaction "inactive"
#    2751     # and remove it as a reset agent
#    2752     if self.connection._nested_transaction:
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2718, in RootTransaction._connection_commit_impl(self)
#    2717 def _connection_commit_impl(self) -> None:
# -> 2718     self.connection._commit_impl()
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1149, in Connection._commit_impl(self)
#    1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
# -> 1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2368, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2366     else:
#    2367         assert exc_info[1] is not None
# -> 2368         raise exc_info[1].with_traceback(exc_info[2])
#    2369 finally:
#    2370     del self._reentrant_error
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1147, in Connection._commit_impl(self)
#    1145         self._log_info("COMMIT")
#    1146 try:
# -> 1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
#    1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:582, in Connection.connection(self)
#     580 if self._dbapi_connection is None:
#     581     try:
# --> 582         return self._revalidate_connection()
#     583     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     584         raise
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:674, in Connection._revalidate_connection(self)
#     672 if self.__can_reconnect and self.invalidated:
#     673     if self._transaction is not None:
# --> 674         self._invalid_transaction()
#     675     self._dbapi_connection = self.engine.raw_connection()
#     676     return self._dbapi_connection
#
# File /workspaces/Data-Project/pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:664, in Connection._invalid_transaction(self)
#     663 def _invalid_transaction(self) -> NoReturn:
# --> 664     raise exc.PendingRollbackError(
#     665         "Can't reconnect until invalid %stransaction is rolled "
#     666         "back.  Please rollback() fully before proceeding"
#     667         % ("savepoint " if self._nested_transaction is not None else ""),
#     668         code="8s2b",
#     669     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %%
# !uv add tqdm

# %%
from tqdm.auto import tqdm

for df_chunk in tqdm(df_iter):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 0it [00:00, ?it/s]
